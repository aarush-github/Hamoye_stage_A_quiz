# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = "latin-1")

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
#Grouping the data for Y2017 and Area
result = df[['Y2017', 'Area']].groupby('Area').sum().sort_values(by='Y2017').reset_index()

# Retrieve the area with the 7th lowest sum
seventh_lowest_area = result.iloc[6]['Area']
result
# Out:
#                            Area       Y2017
# 0                Sudan (former)        0.00
# 1                  Ethiopia PDR        0.00
# 2                       Comoros       59.84
# 3                    Seychelles      442.34
# 4         Sao Tome and Principe    12662.63
# 5                    Cabo Verde    14650.74
# 6                 Guinea-Bissau    19102.77
# 7                       Lesotho    21267.96
# 8                      Botswana    22101.30
# 9                      Djibouti    22729.91
# 10                       Gambia    23154.18
# 11                        Gabon    27979.64
# 12                      Liberia    29342.20
# 13                      Namibia    29874.89
# 14     Central African Republic    29937.00
# 15                        Congo    41181.68
# 16                         Togo    49841.88
# 17                    Mauritius    51114.83
# 18                     Eswatini    54343.33
# 19                 Sierra Leone    55311.33
# ...

# %%
print("The Seventh lowest area:",seventh_lowest_area)
# Out:
# The Seventh lowest area: Guinea-Bissau

# %%
#Given array
array  = np.array([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
#Slicing the matrix
array[:2,1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
df['Item'].unique()
# Out:
# array(['Population', 'Grand Total', 'Vegetal Products', 'Animal Products',
#        'Cereals - Excluding Beer', 'Wheat and products',
#        'Rice and products', 'Barley and products', 'Maize and products',
#        'Rye and products', 'Oats', 'Millet and products',
#        'Sorghum and products', 'Cereals, Other', 'Starchy Roots',
#        'Cassava and products', 'Potatoes and products', 'Sweet potatoes',
#        'Yams', 'Roots, Other', 'Sugar Crops', 'Sugar cane', 'Sugar beet',
#        'Sugar & Sweeteners', 'Sugar (Raw Equivalent)',
#        'Sweeteners, Other', 'Honey', 'Pulses', 'Beans', 'Peas',
#        'Pulses, Other and products', 'Treenuts', 'Nuts and products',
#        'Oilcrops', 'Soyabeans', 'Groundnuts (Shelled Eq)',
#        'Sunflower seed', 'Rape and Mustardseed', 'Cottonseed',
#        'Coconuts - Incl Copra', 'Sesame seed',
#        'Olives (including preserved)', 'Oilcrops, Other',
#        'Vegetable Oils', 'Soyabean Oil', 'Groundnut Oil',
# ...

# %%
#filter the data, to show only Wine values
wine_data = df[df['Item'] == 'Wine']

# Calculate the total sum of wine produced in 2015 and 2018 respectively
wine_2015_sum = wine_data['Y2015'].sum()
wine_2018_sum = wine_data['Y2018'].sum()

print("Total Wine produced in 2015:", wine_2015_sum)
print("Total Wine produced in 2018:", wine_2018_sum)
# Out:
# Total Wine produced in 2015: 4251.8099999999995
# Total Wine produced in 2018: 4039.3199999999997

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
# Selecting the columns 'Y2017' and 'Area'
selected_columns = df[['Y2017', 'Area']]

# Perform a groupby sum aggregation on 'Area'
sum_by_area = selected_columns.groupby('Area').sum()

# Find the area with the highest sum in 2017
area_with_highest_sum = sum_by_area['Y2017'].idxmax()

print("Area with the highest sum in 2017:", area_with_highest_sum)
# Out:
# Area with the highest sum in 2017: Nigeria

# %%
# Filter the data to show only Madagascar data
Protein_data = df[df['Area'] == 'Madagascar']

# %%
Protein_data
# Out:
#        Area Code        Area  Item Code           Item  Element Code  \
# 30715        129  Madagascar       2501     Population           511
# 30716        129  Madagascar       2501     Population          5301
# 30717        129  Madagascar       2901    Grand Total           664
# 30718        129  Madagascar       2901    Grand Total           674
# 30719        129  Madagascar       2901    Grand Total           684
# ...          ...         ...        ...            ...           ...
# 32149        129  Madagascar       2899  Miscellaneous          5142
# 32150        129  Madagascar       2899  Miscellaneous           645
# 32151        129  Madagascar       2899  Miscellaneous           664
# 32152        129  Madagascar       2899  Miscellaneous           674
# 32153        129  Madagascar       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# ...

# %%
A = Protein_data.groupby('Element')['Y2015'].sum()

# %%
A['Protein supply quantity (g/capita/day)']
# Out:
# 173.05

# %%
# Given list
y = [(2, 4), (7, 8), (1, 5, 9)]

# Accessing element 8 using indexing and tuple unpacking
x = y[1][1]  # Access the second tuple (index 1) and then access the second element within that tuple (index 1)

print("Value of x:", x)
# Out:
# Value of x: 8

# %%
# Grouping the data by Element for Y2017 column
B = df.groupby('Element')['Y2017'].sum()

# %%
print("Sum of Processing in Y2017:",B["Processing"])
# Out:
# Sum of Processing in Y2017: 292836.0

# %%
# total number and percentage of missing data in 2014
df['Y2014'].isnull().sum()
# Out:
# 1589

# %%
(df['Y2014'].isnull().sum()/len(df))*100
# Out:
# 2.6073544131401474

# %%
years = ['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']

# %%
for year in years:
  correlation = df['Element Code'].corr(df[year])
  print(f"{year} correlation value: {correlation}")
# Out:
# Y2014 correlation value: 0.024456819495221754
# Y2015 correlation value: 0.023889199301639956
# Y2016 correlation value: 0.023443997584961424
# Y2017 correlation value: 0.02425400776004575
# Y2018 correlation value: 0.02427857195351955

# %%
#Grouping the data by Element col
C = df.groupby('Element').sum()

# %%
#Checking which Year has the highest sum for stock variation
C.loc['Stock Variation','Y2014':]
# Out:
# Y2014    58749.83
# Y2015    34910.99
# Y2016    33140.12
# Y2017    54316.91
# Y2018    20577.91
# Name: Stock Variation, dtype: object

# %%
#Checking for mean and Std for Y2017
df['Y2017'].describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
df.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
total_unique_countries = df['Area'].nunique()
total_unique_countries
# Out:
# 49

# %%
# Given list
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

# Given column names
col = ['Age', 'Nationality', 'Overall']
# Create a DataFrame
df1 = pd.DataFrame(lst, columns=col, index=[1,2,3])

# %%
df1
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
# Given list
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

# Given column names
col = ['Age', 'Nationality', 'Overall']
# Create a DataFrame
df2 = pd.DataFrame(lst, columns=col, index= [i for i in range(1,4)])

# %%
df2
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
# Given list
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

# Given column names
col = ['Age', 'Nationality', 'Overall']
# Create a DataFrame
df3 = pd.DataFrame(lst, columns=['Age','Nationality', 'Overall'], index= [1,2,3])

# %%
df3
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92
